# %% [markdown]
# <a href="https://colab.research.google.com/github/bothwellishumba/SpaceX-Capstone-Project-/blob/main/EDA_WITH_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Objective
#
# To analyze SpaceX launch mission data by loading the dataset into a Db2 database, performing SQL queries, and applying data preparation and feature engineering techniques to identify factors influencing Falcon 9 first-stage landing success, enabling insights into launch costs and competitive bidding opportunities..

# %%
# !pip install sqlalchemy==1.3.9
#!pip install ibm_db_sa
# !pip install ibm_db ibm_db_sa
# !pip install ipython-sql

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %% [markdown]
# **DB2 magic in case of old UI service credentials.**
#
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance before. From the **uri** field of your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/images/URI.jpg">
#
# in the following format
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name**
#
# **DB2 magic in case of new UI service credentials.**
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/servicecredentials.png" width=600>
#
# *   Use the following format.
#
# *   Add security=SSL at the end
#
# **%sql ibm_db_sa://my-username:my-password\@my-hostname:my-port/my-db-name?security=SSL**

# %%
# %sql ibm_db_sa://fqd98471:VzHaYPHpQnNyRXmL@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# ### Task 1
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql SELECT LAUNCH_SITE FROM SPACEX
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('KSC LC-39A',),
#  ('KSC LC-39A',),
#  ('KSC LC-39A',),
#  ('KSC LC-39A',),
#  ('VAFB SLC-4E',),
#  ('KSC LC-39A',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('KSC LC-39A',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('VAFB SLC-4E',),
#  ('VAFB SLC-4E',),
#  ('CCAFS SLC-40',),
#  ('VAFB SLC-4E',),
#  ('KSC LC-39A',),
#  ('CCAFS SLC-40',),
#  ('VAFB SLC-4E',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
#  ('CCAFS SLC-40',),
# ...

# %% [markdown]
# ### Task 2
#
# ##### Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql SELECT * FROM SPACEX WHERE LAUNCH_SITE LIKE 'CCA%' LIMIT 20;
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [(datetime.date(2010, 4, 6), datetime.time(18, 45), 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  (datetime.date(2010, 8, 12), datetime.time(15, 43), 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  (datetime.date(2012, 8, 10), datetime.time(0, 35), 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  (datetime.date(2013, 1, 3), datetime.time(15, 10), 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
# ...

# %% [markdown]
# ### Task 3
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select sum(PAYLOAD_MASS__KG_) as Sum_of_Payload_Mass from SPACEX where CUSTOMER = 'NASA (CRS)'
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [(22007,)]

# %% [markdown]
# ### Task 4
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql select avg(PAYLOAD_MASS__KG_) as Average_Payload_Mass from SPACEX where BOOSTER_VERSION = 'F9 v1.1'
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [(3676,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first successful landing outcome in ground pad was acheived.
#
# *Hint:Use min function*

# %%
# %sql select min(DATE) as First_Date from SPACEX where Landing__Outcome = 'Success (ground pad)'
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [(datetime.date(2017, 1, 5),)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql SELECT booster_version, landing__outcome, payload_mass__kg_ FROM SPACEX WHERE landing__outcome = 'Success (drone ship)' AND payload_mass__kg_ BETWEEN 4000 AND 6000;
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [('F9 FT B1022', 'Success (drone ship)', 4696),
#  ('F9 FT  B1031.2', 'Success (drone ship)', 5200)]

# %% [markdown]
# ### Task 7
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql SELECT mission_outcome, COUNT(*) as Total FROM SPACEX GROUP BY mission_outcome;
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [('Success', 44), ('Success (payload status unclear)', 1)]

# %% [markdown]
# ### Task 8
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql SELECT booster_version FROM SpaceX WHERE payload_mass__kg_ = (SELECT MAX(payload_mass__kg_) FROM SpaceX);
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2',),
#  ('F9 B5 B1058.3',)]

# %% [markdown]
# ### Task 9
#
# ##### List the failed landing_outcomes in drone ship, their booster versions, and launch site names for in year 2015

# %%
# %sql SELECT booster_version, landing__outcome, launch_site, Date FROM SpaceX WHERE landing__outcome = 'Failure (drone ship)' AND Year(date) = 2015;
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [('F9 v1.1 B1012', 'Failure (drone ship)', 'CCAFS LC-40', datetime.date(2015, 10, 1))]

# %% [markdown]
# ### Task 10
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order

# %%
# %sql SELECT (landing__outcome), COUNT(*) AS outcome__count,
ROW_NUMBER() OVER (ORDER BY COUNT(*) DESC) AS rank FROM SpaceX WHERE date BETWEEN '2010-06-04' AND '2017-03-20'
GROUP BY landing__outcome ORDER BY outcome__count DESC;
# Out:
#  * ibm_db_sa://fqd98471:***@b70af05b-76e4-4bca-a1f5-23dbb4c6a74e.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud:32716/bludb;security=SSL
# Done.
# [('No attempt', 7, 1),
#  ('Failure (drone ship)', 2, 2),
#  ('Success (drone ship)', 2, 3),
#  ('Success (ground pad)', 2, 4),
#  ('Controlled (ocean)', 1, 5),
#  ('Failure (parachute)', 1, 6)]
